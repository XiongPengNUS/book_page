# %% [markdown]
# # Application Examples
#
# <br>
#
# <font size='5'><b>Deterministic Linear and Conic Optimization</b></font>
#
# ::::::{grid} 4
# :gutter: 2
#
# :::::{grid-item-card}
# :link: mean_var_portfolio:title
# :link-type: ref
# :shadow: none
#
# Mean-Variance Portfolio
# :::{image} thumbnails/mean_var_portfolio_thumbnail.png
# :height: 160px
# :width: 200px
# :::
# :::::
#
# :::::{grid-item-card}
# :link: sudoku:title
# :link-type: ref
# :shadow: none
#
# Integer Programming for Sudoku
# :::{image} thumbnails/sudoku_thumbnail.png
# :height: 160px
# :width: 200px
# :::
# :::::
#
# :::::{grid-item-card}
# :link: dc_opf:title
# :link-type: ref
# :shadow: none
#
# Optimal DC Power Flow
#
# :::{image} thumbnails/dc_opf_thumbnail.png
# :height: 160px
# :width: 200px
# :::
# :::::
#
# :::::{grid-item-card}
# :link: ac_opf:title
# :link-type: ref
# :shadow: none
#
# Conic Relaxation of Optimal AC Power Flows
#
# :::{image} thumbnails/ac_opf_thumbnail.png
# :height: 160px
# :width: 200px
# :::
# :::::
#
# :::::{grid-item-card}
# :link: ucp:title
# :link-type: ref
# :shadow: none
#
# The Unit Commitment Problem
#
# :::{image} thumbnails/uc_thumbnail.png
# :height: 160px
# :width: 200px
# :::
# :::::
#
# :::::{grid-item-card}
# :link: max_box:title
# :link-type: ref
# :shadow: none
#
# Box with the Maximum Volume
#
# :::{image} thumbnails/max_box_thumbnail.png
# :height: 160px
# :width: 200px
# :::
# :::::
#
# :::::{grid-item-card}
# :link: min_ellipsoid:title
# :link-type: ref
# :shadow: none
#
# Minimal Enclosing Ellipsoid
#
# :::{image} thumbnails/min_ellipsoid_thumbnail.png
# :height: 160px
# :width: 200px
# :::
# :::::
#
# :::::{grid-item-card}
# :link: logit:title
# :link-type: ref
# :shadow: none
#
# Logistic Regression
#
# :::{image} thumbnails/logit_thumbnail.png
# :height: 160px
# :width: 200px
# :::
# :::::
# ::::::
#
#
# ---
#
# <br>
#
# <font size='5'><b>Robust Optimization</b></font>
#
# ::::::{grid} 4
# :gutter: 2
#
# :::::{grid-item-card}
# :link: example_ro_mean_var_portfolio:title
# :link-type: ref
# :shadow: none
#
# Robust Mean-Variance Portfolio
# :::{image} thumbnails/ro_mean_var_portfolio_thumbnail.png
# :height: 160px
# :width: 200px
# :::
# :::::
#
# :::::{grid-item-card}
# :link: ro_portfolio:title
# :link-type: ref
# :shadow: none
#
# Robust Portfolio with Budgeted Uncertainty
# :::{image} thumbnails/ro_portfolio_thumbnail.png
# :height: 160px
# :width: 200px
# :::
# :::::
#
# :::::{grid-item-card}
# :link: robust_cvar_portfolio:title
# :link-type: ref
# :shadow: none
#
# Conditional Value-at-Risk in Robust Portfolio
# :::{image} thumbnails/robust_cvar_portfolio_thumbnail.png
# :height: 160px
# :width: 200px
# :::
# :::::
#
# :::::{grid-item-card}
# :link: aro_lot_sizing:title
# :link-type: ref
# :shadow: none
#
# Adaptive Robust Lot-Sizing
# :::{image} thumbnails/aro_lot_sizing_thumbnail.png
# :height: 160px
# :width: 200px
# :::
# :::::
#
# :::::{grid-item-card}
# :link: ro_inventory_management:title
# :link-type: ref
# :shadow: none
#
# Robust Inventory Management
# :::{image} thumbnails/ro_inventory_management_thumbnail.png
# :height: 160px
# :width: 200px
# :::
# :::::
#
# :::::{grid-item-card}
# :link: ro_medical_scheduling:title
# :link-type: ref
# :shadow: none
#
# Robust Medical Appointment Scheduling
# :::{image} thumbnails/ro_medical_app_thumbnail.png
# :height: 120px
# :width: 200px
# :::
# :::::
#
# ::::::
#
# ---
#
# <br>
#
# <font size='5'><b>Distributionally Robust Optimization</b></font>
